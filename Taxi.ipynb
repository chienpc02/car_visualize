# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('taxi.csv')
df
# Out:
#                                                   Name Service    Province  \
# 0        Xe Liên Tỉnh Thanh Tuyền - Đội Xe Thanh Tuyền    Taxi      Tp Hcm
# 1         Mai Linh - Công Ty Cổ Phần Tập Đoàn Mai Linh    Taxi      Tp Hcm
# 2                          Công Ty Cổ Phần Taxi Hà Nội    Taxi      Hà Nội
# 3          Công Ty Cổ Phần Hợp Tác Đầu Tư & Phát Triển    Taxi      Hà Nội
# 4       én Vàng Taxi - Công Ty Cổ Phần én Vàng Quốc Tế    Taxi   Hải Phòng
# ..                                                 ...     ...         ...
# 146  Sài Gòn Hoàng Long - Công Ty TNHH Một Thành Vi...    Taxi      Tp Hcm
# 147  Ngôi Sao Tương Lai - Công Ty Cổ Phần Ngôi Sao ...    Taxi      Tp Hcm
# 148  Mai Linh Tây Ninh - Công Ty Cổ Phần Mai Linh T...    Taxi    Tây Ninh
# 149         Taxi Duy Hưng - Công Ty TNHH Taxi Duy Hưng    Taxi  Bình Dương
# 150                   Công Ty Taxi Việt Nam Liên Doanh    Taxi      Tp Hcm
#
#                                                Address  \
# ...

# %%
df['Province'].unique()
# Out:
# array(['Tp Hcm', 'Hà Nội', 'Hải Phòng', 'Bình Phước', 'Long An',
#        'Bình Dương', 'Bình Định', 'Khánh Hòa', 'Quảng Trị', 'Vĩnh Phúc',
#        'Đồng Nai', 'Bình Thuận', 'Đà Nẵng', 'Lạng Sơn', 'Quảng Ngãi',
#        'Yên Bái', 'Bà Rịa-Vũng Tàu', 'Đắk Lắk', 'Lâm Đồng', 'Cần Thơ',
#        'Phú Yên', 'Gia Lai', 'Kon Tum', 'Thái Bình', 'Quảng Nam',
#        'Cà Mau', 'Vĩnh Long', 'An Giang', 'Tiền Giang', 'Tây Ninh'],
#       dtype=object)

# %%
df['Province'] = df['Province'].replace({'Tp. Hồ Chí Minh (TPHCM)':'Tp Hcm','Tp. Hải Phòng':'Hải Phòng','Tp. Đà Nẵng':'Đà Nẵng',
                                        'Tp. Cần Thơ':'Cần Thơ'})

# %%
df1 = pd.read_csv('dntaxi.csv')

# %%
df1
# Out:
#                                                   Name  \
# 0    Chi Nhánh Công Ty Cổ Phần Sun Taxi Tại Quảng Bình
# 1                     Công Ty TNHH Taxi Sao Mai Tây Đô
# 2                         CÔNG TY CỔ PHẦN TAXI AN BÌNH
# 3    Công Ty TNHH Một Thành Viên Taxi Thành Công Qu...
# 4           Trung tâm điều hành TAXI Huy Hoàng Kon tum
# ..                                                 ...
# 344     Chi Nhánh Công Ty Cổ Phần Sun Taxi Tại Phú Yên
# 345                     Công Ty TNHH Taxi Đại Hòa Phát
# 346   Công Ty TNHH Một Thành Viên Taxi Hà Nội Bắc Ninh
# 347                     CÔNG TY TNHH TM DV VT TAXI 247
# 348                  HTX VẬN TẢI DU LỊCH TAXI ĐẤT THÉP
#
#                                                Address  \
# 0    Địa chỉ: Số 33 Đường Trần Kinh, Phường Đồng Ph...
# 1    Địa chỉ: Tầng 2, tòa nhà 43, Quang Trung, KDC ...
# 2    Địa chỉ: Tổ dân phố Bình Minh, Thị trấn Trâu Q...
# 3    Địa chỉ: Tổ 3, Khu 10B, Phường Quang Hanh, Thà...
# ...

# %%
df1['Service'] = 'Taxi'

# %%
df1['Phone'] = df1['Tax_Code']

# %%
df1
# Out:
#                                                   Name  \
# 0    Chi Nhánh Công Ty Cổ Phần Sun Taxi Tại Quảng Bình
# 1                     Công Ty TNHH Taxi Sao Mai Tây Đô
# 2                         CÔNG TY CỔ PHẦN TAXI AN BÌNH
# 3    Công Ty TNHH Một Thành Viên Taxi Thành Công Qu...
# 4           Trung tâm điều hành TAXI Huy Hoàng Kon tum
# ..                                                 ...
# 344     Chi Nhánh Công Ty Cổ Phần Sun Taxi Tại Phú Yên
# 345                     Công Ty TNHH Taxi Đại Hòa Phát
# 346   Công Ty TNHH Một Thành Viên Taxi Hà Nội Bắc Ninh
# 347                     CÔNG TY TNHH TM DV VT TAXI 247
# 348                  HTX VẬN TẢI DU LỊCH TAXI ĐẤT THÉP
#
#                                                Address  \
# 0    Địa chỉ: Số 33 Đường Trần Kinh, Phường Đồng Ph...
# 1    Địa chỉ: Tầng 2, tòa nhà 43, Quang Trung, KDC ...
# 2    Địa chỉ: Tổ dân phố Bình Minh, Thị trấn Trâu Q...
# 3    Địa chỉ: Tổ 3, Khu 10B, Phường Quang Hanh, Thà...
# ...

# %%
df = df[['Name','Address','Phone','Province','Service']]
df1 = df1[['Name','Address','Phone','Province','Service']]

# %%
taxi = pd.concat([df,df1])

# %%
taxi = taxi[['Name','Phone','Province','Service']]

# %%
df.to_csv('taxi.csv',index = False)

# %%
data = pd.read_csv('data_car_all.csv')

# %%
data= data[['Name','Phone','Province','Service']]

# %%
data = pd.concat([data,taxi])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10517 entries, 0 to 348
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      10517 non-null  object
#  1   Phone     8628 non-null   object
#  2   Province  10515 non-null  object
#  3   Service   10517 non-null  object
# dtypes: object(4)
# memory usage: 410.8+ KB

# %%
data.to_csv('data_car_all.csv',index = False)

# %%
data['Service'].unique()
# Out:
# array(['Gara', 'Showroom', 'Taxi', 'Thuê xe'], dtype=object)

# %%
data['Service'] = data['Service'].replace('Bắc Giang','Taxi')

# %%
data.dropna(subset=['Province'], inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11015 entries, 0 to 348
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      11015 non-null  object
#  1   Phone     9126 non-null   object
#  2   Province  11015 non-null  object
#  3   Service   11015 non-null  object
# dtypes: object(4)
# memory usage: 430.3+ KB

# %%
data.to_csv('data_car_all.csv',index = False)
